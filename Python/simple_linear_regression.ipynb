# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df=df.drop_duplicates()

# %%
df.count()
# Out:
# Unnamed: 0         30
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
x=df['YearsExperience']
y=df['Salary']

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.count()
# Out:
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
x=df['YearsExperience']
y=df['Salary']

# %% [markdown]
# test split

# %%
# x_train,y_test=train_test_split(x,y,train_size=5,random_state=155)
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=10, random_state=155)

# %%
print(x_train.shape, x_test.shape,y_train.shape, y_test.shape)
type(x_test)
# Out:
# (10,) (20,) (10,) (20,)
# pandas.core.series.Series

# %%
# x_train=x_train.values.reshape(-1,1)
# x_test=x_test.values.reshape(-1,1)
x_train=pd.DataFrame(x_train)
x_test=pd.DataFrame(x_test)
y_train=pd.DataFrame(y_train)
y_train=pd.DataFrame(y_train)

#we re reshaping it because of (x,y) value 
#using pd.dataframe because of pd.array and pd.series

# %%
print(x_train.shape, x_test.shape,y_train.shape, y_test.shape)
# Out:
# (10, 1) (20, 1) (10, 1) (20,)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
plt.xlabel("Original")
plt.ylabel("Predicted")
plt.title("Original vs Predicted")
plt.show()

# %%
from sklearn.metrics import  r2_score;

# %%
# r2score=r2.score(y_test,y_pred)
print("Accuracy=",r2_score(y_test,y_pred))
# Out:
# Accuracy= 0.9389802691390554

# %%
print("NSE= ",mean_squared_error(y_test,y_pred))
# Out:
# NSE=  38016171.87331189

# %%
print("MSE= ",mean_squared_error(y_test,y_pred))
# Out:
# MSE=  38016171.87331189
